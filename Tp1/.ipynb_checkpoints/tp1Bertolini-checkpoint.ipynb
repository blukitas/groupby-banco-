# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', 100)
pd.set_option('display.float_format', '{:.2f}'.format)
#pd.set_option('mode.chained_assignment', None) # Deshabilita SettingWithCopyWarning. Ojo.

# %%
# Cargamos el dataframe
df = pd.read_csv('data/train.csv', index_col='id', parse_dates=['fecha'])

# %%
print(f"Shape: {df.shape}")
print(f"Columnas: {df.columns}")
df.head()
# Out:
# Shape: (240000, 22)
# Columnas: Index(['titulo', 'descripcion', 'tipodepropiedad', 'direccion', 'ciudad',
#        'provincia', 'antiguedad', 'habitaciones', 'garages', 'banos',
#        'metroscubiertos', 'metrostotales', 'idzona', 'lat', 'lng', 'fecha',
#        'gimnasio', 'usosmultiples', 'piscina', 'escuelascercanas',
#        'centroscomercialescercanos', 'precio'],
#       dtype='object')
#                                                    titulo  \
# id
# 254099                                  depto. tipo a-402
# 53461                      condominio horizontal en venta
# 247984              casa en venta urbi 3 recamaras tonala
# 209067  casa sola en toluca zinacantepec con credito i...
# 185997                                     paseos del sol
#
#                                               descripcion     tipodepropiedad  \
# id
# 254099  depto. interior de 80.15m2, consta de sala com...         Apartamento
# 53461   <p>entre sonora y guerrero, atr&aacute;s del h...  Casa en condominio
# 247984  descripcion \nla mejor ubicacion residencial e...                Casa
# 209067  casa en privada con caseta de vigilancia casas...                Casa
# 185997  bonito departamento en excelentes condiciones ...         Apartamento
#
#                               direccion                  ciudad  \
# id
# 254099  Avenida Division del Norte 2005           Benito Juárez
# 53461                        AV. MEXICO  La Magdalena Contreras
# 247984                      Urbi Tonala                  Tonalá
# 209067    IGNACIO MANUEL ALTAMIRANO 128            Zinacantepec
# 185997                  PASEOS DEL SOL                  Zapopan
#
#                provincia  antiguedad  habitaciones  garages  banos  \
# id
# 254099  Distrito Federal         nan          2.00     1.00   2.00
# 53461   Distrito Federal       10.00          3.00     2.00   2.00
# 247984           Jalisco        5.00          3.00     2.00   2.00
# 209067    Edo. de México        1.00          2.00     1.00   1.00
# 185997           Jalisco       10.00          2.00     1.00   1.00
#
#         metroscubiertos  metrostotales   idzona   lat    lng      fecha  \
# id
# 254099            80.00          80.00 23533.00   nan    nan 2015-08-23
# 53461            268.00         180.00 24514.00 19.31 -99.23 2013-06-28
# 247984           144.00         166.00 48551.00   nan    nan 2015-10-17
# 209067            63.00          67.00 53666.00 19.30 -99.69 2012-03-09
# 185997            95.00          95.00 47835.00   nan    nan 2016-06-07
#
#         gimnasio  usosmultiples  piscina  escuelascercanas  \
# id
# 254099      0.00           0.00     0.00              0.00
# 53461       0.00           0.00     0.00              1.00
# 247984      0.00           0.00     0.00              0.00
# 209067      0.00           0.00     0.00              1.00
# 185997      0.00           0.00     0.00              0.00
#
#         centroscomercialescercanos     precio
# id
# 254099                        0.00 2273000.00
# 53461                         1.00 3600000.00
# 247984                        0.00 1200000.00
# 209067                        1.00  650000.00
# 185997                        0.00 1150000.00

# %%
df['tipodepropiedad'].unique()
# Out:
# array(['Apartamento', 'Casa en condominio', 'Casa', 'Terreno',
#        'Terreno comercial', 'Local Comercial', 'Quinta Vacacional',
#        'Oficina comercial', 'Edificio', 'Casa uso de suelo',
#        'Local en centro comercial', 'Bodega comercial', 'Otros', 'Villa',
#        'Duplex', 'Inmuebles productivos urbanos',
#        'Departamento Compartido', 'Nave industrial', 'Rancho',
#        'Terreno industrial', nan, 'Huerta', 'Lote', 'Hospedaje', 'Garage'],
#       dtype=object)

# %%
df[df.tipodepropiedad == 'Apartamento'].head(10)
# Out:
#                                                    titulo  \
# id
# 254099                                  depto. tipo a-402
# 185997                                     paseos del sol
# 126147                     departamento en venta taxqueña
# 44962   pre- venta preciosos depas 2 recamaras con sub...
# 103293  departamento en venta, san pedro garza garcia,...
# 73348   oportunidad, departamento col del valle, 3 rec...
# 257302                                                NaN
# 127666                            hermoso departamento!!!
# 212847                   departamento en arcos de zapopan
# 224685  renta en acapulco con alberca prvada vista a b...
#
#                                               descripcion tipodepropiedad  \
# id
# 254099  depto. interior de 80.15m2, consta de sala com...     Apartamento
# 185997  bonito departamento en excelentes condiciones ...     Apartamento
# 126147  amplio departamento, estancia de sala y comedo...     Apartamento
# 44962   <p>pre-venta de preciosos departamento ecologi...     Apartamento
# 103293  departamento nuevo ,256 m2 de construccion,un ...     Apartamento
# 73348   magnifico departamento con excelente distribuc...     Apartamento
# 257302  -- hav1407e-285 --    excelente departamento e...     Apartamento
# 127666  hermoso departamento con acabados de muy buen ...     Apartamento
# 212847  bonito departamento muy bien ubicado en planta...     Apartamento
# 224685  bonito departamento cerca de sam´s club farall...     Apartamento
#
#                               direccion                  ciudad  \
# id
# 254099  Avenida Division del Norte 2005           Benito Juárez
# 185997                  PASEOS DEL SOL                  Zapopan
# 126147            Condominio Tlalpan 2B                Coyoacán
# 44962    BUENAVISTA DEPTOS CON SUBSIDIO        Villa de Alvarez
# 103293                              NaN  San Pedro Garza García
# 73348                 Pazaje Santa Cruz           Benito Juárez
# 257302                      Rio Mante .           Ciudad Madero
# 127666                     LAS COLONIAS    Atizapán de Zaragoza
# 212847                    ARCO PERTINAX                 Zapopan
# 224685                  RANCHO ACAPULCO      Acapulco de Juárez
#
#                provincia  antiguedad  habitaciones  garages  banos  \
# id
# 254099  Distrito Federal         nan          2.00     1.00   2.00
# 185997           Jalisco       10.00          2.00     1.00   1.00
# 126147  Distrito Federal        5.00          2.00     1.00   1.00
# 44962             Colima        1.00          2.00     1.00   1.00
# 103293        Nuevo León         nan          3.00     2.00   4.00
# 73348   Distrito Federal        5.00          3.00     2.00    nan
# 257302        Tamaulipas        0.00          2.00     1.00   1.00
# 127666    Edo. de México       20.00          2.00     1.00   2.00
# 212847           Jalisco       10.00          2.00     1.00   1.00
# 224685          Guerrero        3.00          2.00     1.00   1.00
#
#         metroscubiertos  metrostotales      idzona   lat    lng      fecha  \
# id
# 254099            80.00          80.00    23533.00   nan    nan 2015-08-23
# 185997            95.00          95.00    47835.00   nan    nan 2016-06-07
# 126147            75.00          90.00    23650.00 19.30 -99.15 2014-03-18
# 44962             58.00            nan     9010.00   nan    nan 2014-01-06
# 103293           256.00            nan   325095.00   nan    nan 2014-12-01
# 73348            127.00         127.00 50003995.00   nan    nan 2016-10-30
# 257302            88.00            nan   104721.00   nan    nan 2016-04-08
# 127666           100.00         100.00    55716.00   nan    nan 2015-01-05
# 212847            84.00          84.00   311049.00   nan    nan 2016-05-22
# 224685            90.00          90.00    37846.00   nan    nan 2014-06-29
#
#         gimnasio  usosmultiples  piscina  escuelascercanas  \
# id
# 254099      0.00           0.00     0.00              0.00
# 185997      0.00           0.00     0.00              0.00
# 126147      0.00           0.00     0.00              0.00
# 44962       0.00           0.00     0.00              1.00
# 103293      0.00           0.00     0.00              0.00
# 73348       0.00           0.00     0.00              1.00
# 257302      0.00           0.00     0.00              0.00
# 127666      0.00           0.00     0.00              1.00
# 212847      0.00           0.00     0.00              0.00
# 224685      0.00           0.00     1.00              1.00
#
#         centroscomercialescercanos     precio
# id
# 254099                        0.00 2273000.00
# 185997                        0.00 1150000.00
# 126147                        1.00 1100000.00
# 44962                         1.00  310000.00
# 103293                        0.00 7200000.00
# 73348                         1.00 4750000.00
# 257302                        0.00  750000.00
# 127666                        1.00  980000.00
# 212847                        0.00  525000.00
# 224685                        1.00 1450000.00

# %%
df['tipodepropiedad'].value_counts()
# Out:
# Casa                             141717
# Apartamento                       57341
# Casa en condominio                19297
# Terreno                            9945
# Local Comercial                    3055
# Oficina comercial                  1741
# Bodega comercial                   1406
# Edificio                           1396
# Terreno comercial                  1326
# Casa uso de suelo                   708
# Quinta Vacacional                   395
# Duplex                              343
# Villa                               340
# Inmuebles productivos urbanos       200
# Rancho                              170
# Local en centro comercial           165
# Departamento Compartido             141
# Otros                               134
# Nave industrial                      76
# Terreno industrial                   31
# Huerta                               20
# Lote                                  5
# Hospedaje                             1
# Garage                                1
# Name: tipodepropiedad, dtype: int64

# %% [markdown]
# df.groupby(['provincia', 'ciudad']).ciudad.value_counts().nlargest(10)

# %%
df['provincia'].value_counts().head(10)
# Out:
# Distrito Federal    58790
# Edo. de México      41607
# Jalisco             21238
# Querétaro           16988
# Nuevo León          15324
# Puebla              10421
# San luis Potosí      8447
# Yucatán              7928
# Morelos              7337
# Veracruz             5762
# Name: provincia, dtype: int64

# %%
df[df.provincia == 'Distrito Federal'].groupby(['tipodepropiedad']).ciudad.value_counts()
# Out:
# tipodepropiedad     ciudad
# Apartamento         Benito Juárez             8714
#                     Cuauhtémoc                4980
#                     Miguel Hidalgo            4767
#                     Alvaro Obregón            3486
#                     Coyoacán                  2116
#                     Tlalpan                   1901
#                     Cuajimalpa de Morelos     1828
#                     Iztapalapa                1412
#                     Azcapotzalco              1178
#                     Gustavo A. Madero         1105
#                     Venustiano Carranza        794
#                     Iztacalco                  577
#                     Tláhuac                    356
#                     La Magdalena Contreras     351
#                     Xochimilco                 250
#                     otra                        13
# Bodega comercial    Iztapalapa                  60
#                     Cuauhtémoc                  44
#                     Gustavo A. Madero           43
#                     Venustiano Carranza         31
#                     Azcapotzalco                27
#                     Iztacalco                   23
#                     Miguel Hidalgo              22
#                     Alvaro Obregón              17
#                     Benito Juárez               13
#                     Tláhuac                     12
#                     Tlalpan                     11
#                     Coyoacán                     9
#                     Xochimilco                   8
#                     Cuajimalpa de Morelos        1
#                                               ...
# Terreno             Azcapotzalco                82
#                     Venustiano Carranza         74
#                     La Magdalena Contreras      57
#                     Cuajimalpa de Morelos       49
#                     Iztacalco                   49
#                     Tláhuac                     24
#                     Milpa Alta                   4
# Terreno comercial   Cuauhtémoc                  28
#                     Tlalpan                     22
#                     Benito Juárez               20
#                     Gustavo A. Madero           20
#                     Iztapalapa                  18
#                     Alvaro Obregón              14
#                     Miguel Hidalgo              14
#                     Venustiano Carranza         14
#                     Xochimilco                  14
#                     Coyoacán                    13
#                     Cuajimalpa de Morelos        4
#                     La Magdalena Contreras       4
#                     Azcapotzalco                 3
#                     Iztacalco                    3
#                     Milpa Alta                   1
#                     Tláhuac                      1
#                     otra                         1
# Terreno industrial  Alvaro Obregón               1
#                     Azcapotzalco                 1
#                     Gustavo A. Madero            1
#                     Iztapalapa                   1
# Villa               Benito Juárez                2
#                     Tlalpan                      1
# Name: ciudad, Length: 238, dtype: int64

# %%
plt.figure(figsize=(15, 15))
sns.heatmap(df.corr(), square=True, annot=True, fmt='.2f');

# %%
df.corr()
# Out:
#                             antiguedad  habitaciones  garages  banos  \
# antiguedad                        1.00          0.16    -0.08  -0.06
# habitaciones                      0.16          1.00     0.24   0.49
# garages                          -0.08          0.24     1.00   0.44
# banos                            -0.06          0.49     0.44   1.00
# metroscubiertos                   0.08          0.52     0.38   0.68
# metrostotales                     0.04          0.37     0.24   0.54
# idzona                            0.03         -0.05    -0.02  -0.00
# lat                              -0.10         -0.01     0.01  -0.05
# lng                               0.01          0.01    -0.00   0.06
# gimnasio                         -0.11         -0.03     0.12   0.08
# usosmultiples                    -0.10         -0.01     0.13   0.10
# piscina                          -0.14         -0.01     0.12   0.13
# escuelascercanas                 -0.01          0.02     0.08  -0.02
# centroscomercialescercanos       -0.01          0.00     0.08  -0.03
# precio                            0.07          0.25     0.35   0.53
#
#                             metroscubiertos  metrostotales  idzona   lat  \
# antiguedad                             0.08           0.04    0.03 -0.10
# habitaciones                           0.52           0.37   -0.05 -0.01
# garages                                0.38           0.24   -0.02  0.01
# banos                                  0.68           0.54   -0.00 -0.05
# metroscubiertos                        1.00           0.73   -0.05 -0.02
# metrostotales                          0.73           1.00   -0.03  0.01
# idzona                                -0.05          -0.03    1.00 -0.06
# lat                                   -0.02           0.01   -0.06  1.00
# lng                                    0.05           0.04    0.10 -0.48
# gimnasio                               0.03           0.02    0.01 -0.04
# usosmultiples                          0.05           0.02    0.00 -0.06
# piscina                                0.06           0.07    0.03 -0.06
# escuelascercanas                      -0.03          -0.05    0.01 -0.07
# centroscomercialescercanos            -0.05          -0.07    0.03 -0.08
# precio                                 0.63           0.51    0.07 -0.16
#
#                              lng  gimnasio  usosmultiples  piscina  \
# antiguedad                  0.01     -0.11          -0.10    -0.14
# habitaciones                0.01     -0.03          -0.01    -0.01
# garages                    -0.00      0.12           0.13     0.12
# banos                       0.06      0.08           0.10     0.13
# metroscubiertos             0.05      0.03           0.05     0.06
# metrostotales               0.04      0.02           0.02     0.07
# idzona                      0.10      0.01           0.00     0.03
# lat                        -0.48     -0.04          -0.06    -0.06
# lng                         1.00      0.00          -0.01     0.02
# gimnasio                    0.00      1.00           0.42     0.37
# usosmultiples              -0.01      0.42           1.00     0.33
# piscina                     0.02      0.37           0.33     1.00
# escuelascercanas           -0.04      0.20           0.20     0.17
# centroscomercialescercanos -0.05      0.14           0.23     0.18
# precio                      0.05      0.15           0.15     0.11
#
#                             escuelascercanas  centroscomercialescercanos  \
# antiguedad                             -0.01                       -0.01
# habitaciones                            0.02                        0.00
# garages                                 0.08                        0.08
# banos                                  -0.02                       -0.03
# metroscubiertos                        -0.03                       -0.05
# metrostotales                          -0.05                       -0.07
# idzona                                  0.01                        0.03
# lat                                    -0.07                       -0.08
# lng                                    -0.04                       -0.05
# gimnasio                                0.20                        0.14
# usosmultiples                           0.20                        0.23
# piscina                                 0.17                        0.18
# escuelascercanas                        1.00                        0.78
# centroscomercialescercanos              0.78                        1.00
# precio                                  0.00                        0.03
#
#                             precio
# antiguedad                    0.07
# habitaciones                  0.25
# garages                       0.35
# banos                         0.53
# metroscubiertos               0.63
# metrostotales                 0.51
# idzona                        0.07
# lat                          -0.16
# lng                           0.05
# gimnasio                      0.15
# usosmultiples                 0.15
# piscina                       0.11
# escuelascercanas              0.00
# centroscomercialescercanos    0.03
# precio                        1.00

# %%
c = df.corr().abs()
s = c.unstack()
so = s.sort_values(kind="quicksort", ascending=False)

#df = pd.DataFrame({'Correlacion':so.index, 'count':so.values})

print(so[so.values < 1.0].head(25))
# Out:
# centroscomercialescercanos  escuelascercanas             0.78
# escuelascercanas            centroscomercialescercanos   0.78
# metroscubiertos             metrostotales                0.73
# metrostotales               metroscubiertos              0.73
# banos                       metroscubiertos              0.68
# metroscubiertos             banos                        0.68
#                             precio                       0.63
# precio                      metroscubiertos              0.63
# banos                       metrostotales                0.54
# metrostotales               banos                        0.54
# banos                       precio                       0.53
# precio                      banos                        0.53
# habitaciones                metroscubiertos              0.52
# metroscubiertos             habitaciones                 0.52
# metrostotales               precio                       0.51
# precio                      metrostotales                0.51
# habitaciones                banos                        0.49
# banos                       habitaciones                 0.49
# lat                         lng                          0.48
# lng                         lat                          0.48
# garages                     banos                        0.44
# banos                       garages                      0.44
# gimnasio                    usosmultiples                0.42
# usosmultiples               gimnasio                     0.42
# garages                     metroscubiertos              0.38
# dtype: float64

# %%
so = df.groupby(by=['provincia','tipodepropiedad']).size().sort_values(kind="quicksort", ascending=False)
#print(so)
#print(so[so.values < 1.0].head(25))

# %%
### Tipos de propiedas principales ###
tiposPrincipales = df.tipodepropiedad.value_counts().sort_values(kind="quicksort", ascending=False).to_frame()
print(tiposPrincipales.plot(kind='bar'))
#print(tiposPrincipales.values)
tiposPrincipales['porcentaje'] = tiposPrincipales.values / tiposPrincipales.values.sum()
#print(tiposPrincipales.porcentaje)
print(tiposPrincipales.head(10))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
#                     tipodepropiedad  porcentaje
# Casa                         141717        0.59
# Apartamento                   57341        0.24
# Casa en condominio            19297        0.08
# Terreno                        9945        0.04
# Local Comercial                3055        0.01
# Oficina comercial              1741        0.01
# Bodega comercial               1406        0.01
# Edificio                       1396        0.01
# Terreno comercial              1326        0.01
# Casa uso de suelo               708        0.00

# %%
    df[df.tipodepropiedad.isin(tiposPrincipales.head(5).tipodepropiedad.index)].groupby(['provincia']).tipodepropiedad.value_counts()
    #print(tiposPrincipales.head(5).tipodepropiedad.index)
# Out:
# provincia              tipodepropiedad
# Aguascalientes         Casa                  1340
#                        Casa en condominio     197
#                        Terreno                 86
#                        Apartamento             47
#                        Local Comercial         31
# Baja California Norte  Casa                  2769
#                        Apartamento            196
#                        Casa en condominio     166
#                        Terreno                 24
#                        Local Comercial         17
# Baja California Sur    Casa                  1473
#                        Apartamento             82
#                        Terreno                 52
#                        Casa en condominio      34
#                        Local Comercial         21
# Campeche               Casa                   210
#                        Terreno                 20
#                        Casa en condominio      11
#                        Apartamento              7
#                        Local Comercial          7
# Chiapas                Casa                   903
#                        Terreno                100
#                        Apartamento             52
#                        Local Comercial         16
#                        Casa en condominio      14
# Chihuahua              Casa                  3891
#                        Terreno                230
#                        Local Comercial        223
#                        Apartamento             41
#                        Casa en condominio      10
#                                              ...
# Tabasco                Casa                   722
#                        Apartamento             97
#                        Terreno                 79
#                        Casa en condominio      30
#                        Local Comercial         10
# Tamaulipas             Casa                  1822
#                        Apartamento            232
#                        Terreno                114
#                        Local Comercial         37
#                        Casa en condominio      33
# Tlaxcala               Casa                   716
#                        Terreno                 35
#                        Apartamento             31
#                        Casa en condominio      29
#                        Local Comercial         11
# Veracruz               Casa                  4445
#                        Apartamento            565
#                        Terreno                422
#                        Casa en condominio      91
#                        Local Comercial         58
# Yucatán                Casa                  6472
#                        Apartamento            573
#                        Casa en condominio     321
#                        Terreno                250
#                        Local Comercial         98
# Zacatecas              Casa                    80
#                        Terreno                  4
#                        Casa en condominio       3
#                        Apartamento              1
#                        Local Comercial          1
# Name: tipodepropiedad, Length: 160, dtype: int64

# %%
df[df.tipodepropiedad.isin(tiposPrincipales.head(5).tipodepropiedad.index)].groupby(['provincia']).tipodepropiedad.value_counts()
#print(tiposPrincipales.head(5).tipodepropiedad.index)
# Out:
# provincia              tipodepropiedad
# Aguascalientes         Casa                  1340
#                        Casa en condominio     197
#                        Terreno                 86
#                        Apartamento             47
#                        Local Comercial         31
# Baja California Norte  Casa                  2769
#                        Apartamento            196
#                        Casa en condominio     166
#                        Terreno                 24
#                        Local Comercial         17
# Baja California Sur    Casa                  1473
#                        Apartamento             82
#                        Terreno                 52
#                        Casa en condominio      34
#                        Local Comercial         21
# Campeche               Casa                   210
#                        Terreno                 20
#                        Casa en condominio      11
#                        Apartamento              7
#                        Local Comercial          7
# Chiapas                Casa                   903
#                        Terreno                100
#                        Apartamento             52
#                        Local Comercial         16
#                        Casa en condominio      14
# Chihuahua              Casa                  3891
#                        Terreno                230
#                        Local Comercial        223
#                        Apartamento             41
#                        Casa en condominio      10
#                                              ...
# Tabasco                Casa                   722
#                        Apartamento             97
#                        Terreno                 79
#                        Casa en condominio      30
#                        Local Comercial         10
# Tamaulipas             Casa                  1822
#                        Apartamento            232
#                        Terreno                114
#                        Local Comercial         37
#                        Casa en condominio      33
# Tlaxcala               Casa                   716
#                        Terreno                 35
#                        Apartamento             31
#                        Casa en condominio      29
#                        Local Comercial         11
# Veracruz               Casa                  4445
#                        Apartamento            565
#                        Terreno                422
#                        Casa en condominio      91
#                        Local Comercial         58
# Yucatán                Casa                  6472
#                        Apartamento            573
#                        Casa en condominio     321
#                        Terreno                250
#                        Local Comercial         98
# Zacatecas              Casa                    80
#                        Terreno                  4
#                        Casa en condominio       3
#                        Apartamento              1
#                        Local Comercial          1
# Name: tipodepropiedad, Length: 160, dtype: int64

# %%
df['amenities'] = df.gimnasio + df.usosmultiples + df.piscina #+ df.escuelascercanas + df.centroscomercialescercanos
df['plus']  = df.habitaciones + df.banos + df.garages + df.gimnasio + df.usosmultiples + df.piscina + df.escuelascercanas + df.centroscomercialescercanos

# %%
# df[['amenities', 'precio']].plot(x ='amenities', y='precio', kind = '')
dfProps = df[df.tipodepropiedad.isin(tiposPrincipales.head(5).tipodepropiedad.index)]

from matplotlib.ticker import AutoMinorLocator
fig = plt.figure(figsize=(18,6))
ax1 = sns.boxplot('amenities', "precio", data=dfProps) #, hue='modelLine')
ax1.minorticks_on()
ax1.xaxis.set_minor_locator(AutoMinorLocator(2))
ax1.grid(which='minor', axis='x', linewidth=1)

# %%
# Barras desmembrando eso
# Distribucion amenities
#df[['gimnasio', 'usosmultiples', 'piscina', 'amenities']].groupby('amenities').sum().plot(kind='bar');
# Precio vs amenities
#df[['amenities', 'precio']].groupby('amenities').agg({'precio':np.mean}).plot(kind='bar');

# Plot
plt.figure(figsize=(12,9), dpi= 80)
parallel_coordinates(df[['gimnasio', 'usosmultiples', 'piscina']], 'cut', colormap='Dark2')

# Lighten borders
plt.gca().spines["top"].set_alpha(0)
plt.gca().spines["bottom"].set_alpha(.3)
plt.gca().spines["right"].set_alpha(0)
plt.gca().spines["left"].set_alpha(.3)

plt.title('Parallel Coordinated of Diamonds', fontsize=22)
plt.grid(alpha=0.3)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
df['amenities'].head()

# %%
# df[['amenities', 'precio']].plot(x ='amenities', y='precio', kind = '')
dfProps = df[df.tipodepropiedad.isin(tiposPrincipales.head(5).tipodepropiedad.index)]

from matplotlib.ticker import AutoMinorLocator
fig = plt.figure(figsize=(18,6))
ax1 = sns.boxplot('plus', "precio", data=dfProps) #, hue='modelLine')
ax1.minorticks_on()
ax1.xaxis.set_minor_locator(AutoMinorLocator(2))
ax1.grid(which='minor', axis='x', linewidth=1)

# %%
df['banos-metros'] = df['metroscubiertos'] / df['banos']

fig, ax =plt.subplots(1,2)
sns.barplot(x=df['banos-metros'],y=df['precio'],ax=ax[0])
# sns.barplot(x=df['gimnasio'],y=df['precio_usd'],ax=ax[1])
fig.show()
# Out:
# C:\Users\Lucas\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
